# %% [markdown]
# # LlamaIndex Code Interpreter example
# Code interpreter example using Llama Index.
#
# Please set your OpenAI API key and AgentOps key in a local .env file for load_dotenv():
# ```
# OPENAI_API_KEY=sk...
# AGENTOPS_API_KEY=
# LLAMA_CLOUD_API_KEY=
# ```
# or set it in the environment explicity using
# ```
# import os
# os.environ["OPENAI_API_KEY"] = "sk..."
# os.environ["AGENTOPS_API_KEY"] = ".."
# os.environ["LLAMA_CLOUD_API_KEY"] = ".."
# ```

# %%
# %pip install llama-index-agent-openai
# %pip install llama-index-llms-openai
# %pip install llama-index-tools-code-interpreter
# Out:
# Collecting llama-index-agent-openai
#   Using cached llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Collecting llama-index-core<0.12.0,>=0.11.0
#   Using cached llama_index_core-0.11.23-py3-none-any.whl (1.6 MB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.9
#   Using cached llama_index_llms_openai-0.2.16-py3-none-any.whl (13 kB)
# Collecting openai>=1.14.0
#   Downloading openai-1.54.4-py3-none-any.whl (389 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (6.0.2)
# Collecting SQLAlchemy[asyncio]>=1.4.49
#   Using cached SQLAlchemy-2.0.36-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Collecting aiohttp<4.0.0,>=3.8.6
#   Using cached aiohttp-3.11.2-cp311-cp311-macosx_11_0_arm64.whl (453 kB)
# Collecting dataclasses-json
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8
#   Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Collecting filetype<2.0.0,>=1.2.0
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Requirement already satisfied: httpx in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.6.0)
# Collecting networkx>=3.0
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting nltk>3.8.1
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting numpy<2.0.0
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Collecting pillow>=9.0.0
#   Using cached pillow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl (3.0 MB)
# Collecting pydantic<3.0.0,>=2.7.0
#   Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Requirement already satisfied: requests>=2.31.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0
#   Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting tiktoken>=0.3.3
#   Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl (982 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 14.1 MB/s eta 0:00:0000:0100:01
# Collecting tqdm<5.0.0,>=4.66.1
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.12.2)
# Collecting typing-inspect>=0.8.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting wrapt
#   Using cached wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai) (4.6.2.post1)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.7.1-cp311-cp311-macosx_11_0_arm64.whl (303 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.5/303.5 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.3.1)
# Collecting aiohappyeyeballs>=2.3.0
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.2.0)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Collecting propcache>=0.2.0
#   Using cached propcache-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (45 kB)
# Collecting yarl<2.0,>=1.17.0
#   Using cached yarl-1.17.2-cp311-cp311-macosx_11_0_arm64.whl (91 kB)
# Requirement already satisfied: idna>=2.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (3.10)
# Requirement already satisfied: certifi in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.14.0)
# Collecting click
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.6/284.6 kB 18.6 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.23.4
#   Using cached pydantic_core-2.23.4-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.2.3)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-3.1.1-cp311-cp311-macosx_11_0_universal2.whl (272 kB)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Requirement already satisfied: packaging>=17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.2)
# Installing collected packages: filetype, dirtyjson, wrapt, tqdm, tenacity, SQLAlchemy, regex, pydantic-core, propcache, pillow, numpy, networkx, mypy-extensions, multidict, marshmallow, joblib, jiter, greenlet, fsspec, frozenlist, distro, click, annotated-types, aiohappyeyeballs, yarl, typing-inspect, tiktoken, pydantic, nltk, deprecated, aiosignal, openai, dataclasses-json, aiohttp, llama-index-core, llama-index-llms-openai, llama-index-agent-openai
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.3 aiohttp-3.11.2 aiosignal-1.3.1 annotated-types-0.7.0 click-8.1.7 dataclasses-json-0.6.7 deprecated-1.2.15 dirtyjson-1.0.8 distro-1.9.0 filetype-1.2.0 frozenlist-1.5.0 fsspec-2024.10.0 greenlet-3.1.1 jiter-0.7.1 joblib-1.4.2 llama-index-agent-openai-0.3.4 llama-index-core-0.11.23 llama-index-llms-openai-0.2.16 marshmallow-3.23.1 multidict-6.1.0 mypy-extensions-1.0.0 networkx-3.4.2 nltk-3.9.1 numpy-1.26.4 openai-1.54.4 pillow-11.0.0 propcache-0.2.0 pydantic-2.9.2 pydantic-core-2.23.4 regex-2024.11.6 tenacity-8.5.0 tiktoken-0.8.0 tqdm-4.67.0 typing-inspect-0.9.0 wrapt-1.16.0 yarl-1.17.2
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (0.2.16)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-llms-openai) (0.11.23)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-llms-openai) (1.54.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.11.2)
# Requirement already satisfied: dataclasses-json in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.10.0)
# Requirement already satisfied: httpx in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.7.1)
# Requirement already satisfied: sniffio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.17.2)
# Requirement already satisfied: idna>=2.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.10)
# Requirement already satisfied: certifi in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.2)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-tools-code-interpreter
#   Using cached llama_index_tools_code_interpreter-0.3.0-py3-none-any.whl (2.9 kB)
# Collecting llama-index-core<0.13.0,>=0.12.0
#   Using cached llama_index_core-0.12.0-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.11.2)
# Requirement already satisfied: dataclasses-json in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2024.10.0)
# Requirement already satisfied: httpx in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.9.1)
# Requirement already satisfied: numpy in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.9.0)
# Requirement already satisfied: wrapt in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.17.2)
# Requirement already satisfied: click in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (8.1.7)
# Requirement already satisfied: joblib in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (3.23.1)
# Requirement already satisfied: anyio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.0.7)
# Requirement already satisfied: sniffio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-tools-code-interpreter) (24.2)
# Installing collected packages: llama-index-core, llama-index-tools-code-interpreter
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.11.23
#     Uninstalling llama-index-core-0.11.23:
#       Successfully uninstalled llama-index-core-0.11.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-agent-openai 0.3.4 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-llms-openai 0.2.16 requires llama-index-core<0.12.0,>=0.11.7, but you have llama-index-core 0.12.0 which is incompatible.
# Successfully installed llama-index-core-0.12.0 llama-index-tools-code-interpreter-0.3.0
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !pip install llama-index python-dotenv
# Out:
# Requirement already satisfied: llama-index in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (0.11.23)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.23 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.11.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.6.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.4.0,>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.54.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.11.2)
# Requirement already satisfied: dataclasses-json in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2024.10.0)
# Requirement already satisfied: httpx in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.4.2)
# Requirement already satisfied: numpy<2.0.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.5)
# Requirement already satisfied: pandas in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.14)
# Requirement already satisfied: click in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.17.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.7)
# Requirement already satisfied: idna in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.10)
# Requirement already satisfied: sniffio in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import openai
from llama_index.agent.openai import OpenAIAgent

# %%
# Import and initialize our tool spec
from llama_index.tools.code_interpreter.base import CodeInterpreterToolSpec

code_spec = CodeInterpreterToolSpec()

tools = code_spec.to_tool_list()

# %%
# Create the Agent with our tools
agent = OpenAIAgent.from_tools(tools, verbose=True)

# %%
# Prime the Agent to use the tool
print(
    agent.chat(
        "Can you help me write some python code to pass to the code_interpreter tool"
    )
)
# Out:
# Added user message to memory: Can you help me write some python code to pass to the code_interpreter tool
# Of course! What specific task or problem would you like the Python code to solve or address?

# %%
print(
    agent.chat(
        """There is a movies_500.csv file in the `data` directory (relative path).
                 Can you write and execute code to tell me columns does it have?"""
    )
)
# Out:
# Added user message to memory: There is a movies_500.csv file in the `data` directory (relative path).
#                  Can you write and execute code to tell me columns does it have?
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"import pandas as pd\n\n# Load the CSV file\ndf = pd.read_csv('data/movies_500.csv')\n\n# Get the columns of the DataFrame\ncolumns = df.columns\n\n# Convert the columns to a list\ncolumns_list = columns.tolist()\n\n# Print the list of columns\nprint(columns_list)"}
# Got output: StdOut:
# b"['index', 'budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count', 'cast', 'crew', 'director']\n"
# StdErr:
# b''
# ========================
#
# The columns in the `movies_500.csv` file are as follows:
# - index
# - budget
# - genres
# - homepage
# - id
# - keywords
# - original_language
# - original_title
# - overview
# - popularity
# - production_companies
# - production_countries
# - release_date
# - revenue
# - runtime
# - spoken_languages
# - status
# - tagline
# - title
# - vote_average
# - vote_count
# - cast
# - crew
# - director
#
# If you need any further assistance or have any other questions, feel free to ask!

# %%
print(agent.chat("What are the top 10 movies"))
# Out:
# Added user message to memory: What are the top 10 movies
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"# Display the top 10 movies based on popularity\ntop_10_movies = df[['title', 'popularity']].nlargest(10, 'popularity')\n\n# Print the top 10 movies\nprint(top_10_movies)"}
# Got output: StdOut:
# b''
# StdErr:
# b'Traceback (most recent call last):\n  File "<string>", line 2, in <module>\nNameError: name \'df\' is not defined\n'
# ========================
#
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"import pandas as pd\n\n# Load the CSV file\ndf = pd.read_csv('data/movies_500.csv')\n\n# Display the top 10 movies based on popularity\ntop_10_movies = df[['title', 'popularity']].nlargest(10, 'popularity')\n\n# Print the top 10 movies\nprint(top_10_movies)"}
# Got output: StdOut:
# b'                                                 title  popularity\n95                                        Interstellar  724.247784\n94                             Guardians of the Galaxy  481.098624\n127                                 Mad Max: Fury Road  434.278564\n28                                      Jurassic World  418.708552\n199  Pirates of the Caribbean: The Curse of the Bla...  271.972889\n82                      Dawn of the Planet of the Apes  243.791743\n200              The Hunger Games: Mockingjay - Part 1  206.227151\n88                                          Big Hero 6  203.734590\n108                                 Terminator Genisys  202.042635\n26                          Captain America: Civil War  198.372395\n'
# StdErr:
# b''
# ========================
#
# The top 10 movies based on popularity from the `movies_500.csv` file are as follows:
#
# 1. Interstellar - Popularity: 724.247784
# 2. Guardians of the Galaxy - Popularity: 481.098624
# 3. Mad Max: Fury Road - Popularity: 434.278564
# 4. Jurassic World - Popularity: 418.708552
# 5. Pirates of the Caribbean: The Curse of the Black Pearl - Popularity: 271.972889
# 6. Dawn of the Planet of the Apes - Popularity: 243.791743
# 7. The Hunger Games: Mockingjay - Part 1 - Popularity: 206.227151
# 8. Big Hero 6 - Popularity: 203.734590
# 9. Terminator Genisys - Popularity: 202.042635
# 10. Captain America: Civil War - Popularity: 198.372395
#
# If you have any more questions or need further assistance, feel free to ask!

# %%
print(agent.chat("Can you make a graph of the top 10 most expensive movies from a budget perspective"))
# Out:
# Added user message to memory: Can you make a graph of the top 10 most expensive movies from a budget perspective
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"import matplotlib.pyplot as plt\n\n# Display the top 10 most expensive movies based on budget\ntop_10_expensive_movies = df[['title', 'budget']].nlargest(10, 'budget')\n\n# Create a bar graph\nplt.figure(figsize=(12, 6))\nplt.bar(top_10_expensive_movies['title'], top_10_expensive_movies['budget'])\nplt.xlabel('Movie Title')\nplt.ylabel('Budget')\nplt.title('Top 10 Most Expensive Movies')\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.show()"}
# Got output: StdOut:
# b''
# StdErr:
# b'Traceback (most recent call last):\n  File "<string>", line 4, in <module>\nNameError: name \'df\' is not defined\n'
# ========================
#
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"import pandas as pd\nimport matplotlib.pyplot as plt\n\n# Load the CSV file\ndf = pd.read_csv('data/movies_500.csv')\n\n# Display the top 10 most expensive movies based on budget\ntop_10_expensive_movies = df[['title', 'budget']].nlargest(10, 'budget')\n\n# Create a bar graph\nplt.figure(figsize=(12, 6))\nplt.bar(top_10_expensive_movies['title'], top_10_expensive_movies['budget'])\nplt.xlabel('Movie Title')\nplt.ylabel('Budget')\nplt.title('Top 10 Most Expensive Movies')\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.show()"}
# Got output: StdOut:
# b'Figure(1200x600)\n'
# StdErr:
# b''
# ========================
#
# The bar graph displaying the top 10 most expensive movies based on budget has been generated. Unfortunately, I cannot display the graph here, but you can see it in your local environment.
#
# If you have any more questions or need further assistance, feel free to ask!

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl (254 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.55.0-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl (64 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from matplotlib) (11.0.0)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/arunesh/github/llm_agents/.venv_1/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.0 kiwisolver-1.4.7 matplotlib-3.9.2 pyparsing-3.2.0
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
print(
    agent.chat(
        "I cant see the plot - can you save it locally with file name `output.png`?"
    )
)
# Out:
# Added user message to memory: I cant see the plot - can you save it locally with file name `output.png`?
# === Calling Function ===
# Calling function: code_interpreter with args: {"code":"import pandas as pd\nimport matplotlib.pyplot as plt\n\n# Load the CSV file\ndf = pd.read_csv('data/movies_500.csv')\n\n# Display the top 10 most expensive movies based on budget\ntop_10_expensive_movies = df[['title', 'budget']].nlargest(10, 'budget')\n\n# Create a bar graph\nplt.figure(figsize=(12, 6))\nplt.bar(top_10_expensive_movies['title'], top_10_expensive_movies['budget'])\nplt.xlabel('Movie Title')\nplt.ylabel('Budget')\nplt.title('Top 10 Most Expensive Movies')\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.savefig('output.png')"}
# Got output: StdOut:
# b''
# StdErr:
# b''
# ========================
#
# The plot of the top 10 most expensive movies based on budget has been saved locally as `output.png`. You can download and view the plot using that file.
#
# If you need any further assistance or have any other requests, feel free to let me know!

# %% [markdown]
# ![plot](./output.png)
